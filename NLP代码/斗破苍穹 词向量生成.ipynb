# %%
import collections
import math
import random
import jieba
import numpy as np
from six.moves import xrange
import tensorflow as tf

# %%
def read_data():
    """
    对要训练的文本进行处理，最后把文本的内容的所有词放在一个列表中
    """
    #读取停用词
    stop_words = []
    with open('C:/Users/dell/Desktop/word2vec-tensorflow-master/stop_words.txt',"r",encoding="UTF-8") as f:
        line = f.readline()
        while line:
            stop_words.append(line[:-1])
            line = f.readline()
    stop_words = set(stop_words)
    print('停用词读取完毕，共{n}个词'.format(n=len(stop_words)))

    # 读取文本，预处理，分词，得到词典
    raw_word_list = []
    with open('C:/Users/dell/Desktop/word2vec-tensorflow-master/doupocangqiong.txt',"r", encoding='UTF-8') as f:
        line = f.readline()
        while line:
            while '\n' in line:
                line = line.replace('\n','')
            while ' ' in line:
                line = line.replace(' ','')
            while '…' in line:
                line = line.replace('…','')
            while '”' in line:
                line = line.replace('”','')
            if len(line)>0: # 如果句子非空
                raw_words = list(jieba.cut(line,cut_all=False))
                raw_word_list.extend(raw_words)
            line=f.readline()
    return raw_word_list

# %%
word_list =read_data()
# Out:
# 停用词读取完毕，共1893个词

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    print("count",len(count))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
data, count, dictionary, reverse_dictionary = build_dataset(word_list)
# Out:
# count 50000

# %%
data_index = 0

# %%
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],'->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 32417 《 -> 12889 斗破
# 32417 《 -> 32416 ﻿
# 12889 斗破 -> 32417 《
# 12889 斗破 -> 7446 苍穹
# 7446 苍穹 -> 12889 斗破
# 7446 苍穹 -> 32418 》
# 32418 》 -> 7446 苍穹
# 32418 》 -> 25329 第一章

# %%
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],'->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 32417 《 -> 12889 斗破
# 32417 《 -> 32416 ﻿
# 12889 斗破 -> 32417 《
# 12889 斗破 -> 7446 苍穹
# 7446 苍穹 -> 12889 斗破
# 7446 苍穹 -> 32418 》
# 32418 》 -> 7446 苍穹
# 32418 》 -> 25329 第一章

# %%
batch_size = 128
embedding_size = 128  
skip_window = 1       
num_skips = 2         
valid_size = 9       
valid_window = 100  
num_sampled = 64

# %%
valid_word = ['萧炎','灵魂','火焰','萧薰儿','药老','天阶',"云岚宗","乌坦城","惊诧"]
valid_examples =[dictionary[li] for li in valid_word]

# %%
valid_examples
# Out:
# [8, 102, 75, 7641, 13733, 2015, 304, 1669, 1987]

# %%
graph = tf.Graph()

# %%
with graph.as_default():

    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    with tf.device('/cpu:0'):

        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)


        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]),dtype=tf.float32)

    loss = tf.reduce_mean(tf.nn.nce_loss(weights=nce_weights,
                                         biases=nce_biases, 
                                         inputs=embed, 
                                         labels=train_labels,
                                         num_sampled=num_sampled, 
                                         num_classes=vocabulary_size))


    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    #维度 [embeddings_size,1] 
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    #维度 [valid_size,embeddings_size] 
    similarity = tf.matmul(valid_embeddings, normalized_embeddings, transpose_b=True)
    #维度 [valid_size,vocabulary_size]
    init = tf.global_variables_initializer()
    print(normalized_embeddings)
# Out:
# Tensor("truediv:0", shape=(50000, 128), dtype=float32)

# %%
num_steps= 3000000

# %%
with tf.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    init.run()
    print("Initialized")
    saver=tf.train.Saver(max_to_keep=10)
    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}


        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000

            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[:top_k]
                log_str = "Nearest to %s:" % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
            
                print(log_str)
            saver.save(session,'D:/sess/',global_step=1000)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  289.82305908203125
# Nearest to 萧炎: 萧炎, 先打, 只留, 听错, 冰雾, 一只, 这云, 血浪,
# Nearest to 灵魂: 灵魂, 陆牧, 探亲, 怪力, 费去, 无害, 回龙, 心急火燎,
# Nearest to 火焰: 火焰, 一前一后, 漫场, 章大, 以三人, 流窜, 内脏, 这雷,
# Nearest to 萧薰儿: 萧薰儿, 上绘, 师欠, 请动, 想到, 看着办, 门门主, 攻城,
# Nearest to 药老: 药老, 若干, 天而起, 咆哮声, 小规模, 这不怪, 电击, 砸,
# Nearest to 天阶: 天阶, 爬上来, 周折, 紧绷着, 留印, 可蛇, 沉默, 怨言,
# Nearest to 云岚宗: 云岚宗, 老落, 巨熊, 那人醒, 老杂, 买主, 坑痕, 三心二意,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 第六, 唉, 略有, 成蓝, 接战,
# Nearest to 惊诧: 惊诧, 本皇, 云韵玉, 眼珠子, 多数, 不早, 回过, 玉袖,
# Average loss at step  2000 :  110.82173763370514
# Average loss at step  4000 :  50.454421230316164
# Average loss at step  6000 :  31.472390153884888
# Average loss at step  8000 :  22.373685292959212
# Average loss at step  10000 :  17.700019909262657
# Nearest to 萧炎: 萧炎, 她, 他, 淫, 俏皮, 我, 因此, 率先,
# Nearest to 灵魂: 灵魂, 无害, 陆牧, 皱着眉头, 稳固, 倩影, 划下, ，,
# Nearest to 火焰: 火焰, 一前一后, 想着, 章大, 波纹, 庆贺, 咬牙, 无用,
# Nearest to 萧薰儿: 萧薰儿, 想到, 支持, 请动, 高, 脑中, 瓶, 微竖,
# Nearest to 药老: 药老, 咆哮声, 砸, 挥, 速战速决, 雅涵, 看看, 双方,
# Nearest to 天阶: 天阶, 沉默, 二十岁, 许久, 还给, 不慎, 一扯, 旋即,
# Nearest to 云岚宗: 云岚宗, 精神, 的确, 咕, 娇躯, 台上, 坑痕, 巨响,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 略有, 不用, 喊价, 萧厉,
# Nearest to 惊诧: 惊诧, 由于, 回过, 迷, 那卷, 惑, 齐全, 魔,
# Average loss at step  12000 :  13.595442289590835
# Average loss at step  14000 :  11.053979106068612
# Average loss at step  16000 :  9.444193991422653
# Average loss at step  18000 :  8.468010264873504
# Average loss at step  20000 :  7.680692128777504
# Nearest to 萧炎: 萧炎, 他, 她, 屹立, 古河, 淫, 不由得, 初步,
# Nearest to 灵魂: 灵魂, 陆牧, 无害, 倩影, 怪力, 划下, 实现, 稳固,
# Nearest to 火焰: 火焰, 一前一后, 想着, 波纹, 庆贺, 不受, 承认, 遥远,
# Nearest to 萧薰儿: 萧薰儿, 想到, 愿助, 请动, 支持, 瓶, 脑中, 微竖,
# Nearest to 药老: 药老, 咆哮声, 挥, 砸, 速战速决, 看看, 雅涵, 双方,
# Nearest to 天阶: 天阶, 沉默, 二十岁, 不慎, 紧绷着, 许久, 还给, 一扯,
# Nearest to 云岚宗: 云岚宗, 精神, 咕, 娇躯, 坑痕, 的确, 低阶, 老杂,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 第六, 十六七, 略有, 一弹, 喊价,
# Nearest to 惊诧: 惊诧, 由于, 回过, 那卷, 迷, 眼珠子, 齐全, 魔,
# Average loss at step  22000 :  7.209941016435623
# Average loss at step  24000 :  6.711857536792755
# Average loss at step  26000 :  6.683352863073349
# Average loss at step  28000 :  6.140191727399826
# Average loss at step  30000 :  5.865688012123108
# Nearest to 萧炎: 萧炎, 他, 她, 后者, 其, 屹立, 紫研, 古河,
# Nearest to 灵魂: 灵魂, 陆牧, 无害, 倩影, 划下, 千层, 龙力, 怪力,
# Nearest to 火焰: 火焰, 想着, 一前一后, 波纹, 不受, 庆贺, 修炼法, 乃是,
# Nearest to 萧薰儿: 萧薰儿, 想到, 请动, 愿助, 支持, 瓶, 脑中, 微竖,
# Nearest to 药老: 药老, 咆哮声, 看看, 挥, 砸, 速战速决, 这不怪, 雅涵,
# Nearest to 天阶: 天阶, 沉默, 二十岁, 不慎, 紧绷着, 韩冲, 还给, 许久,
# Nearest to 云岚宗: 云岚宗, 精神, 咕, 四个, 娇躯, 坑痕, 老杂, 的确,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 第六, 十六七, 略有, 蜈崖, 一弹,
# Nearest to 惊诧: 惊诧, 回过, 那卷, 由于, 眼珠子, 迷, 齐全, 注意,
# Average loss at step  32000 :  5.969457833647728
# Average loss at step  34000 :  5.572923622131348
# Average loss at step  36000 :  5.121695828437805
# Average loss at step  38000 :  4.813739042401314
# Average loss at step  40000 :  4.74374455344677
# Nearest to 萧炎: 萧炎, 他, 她, 后者, 紫研, 他们, 其, 我,
# Nearest to 灵魂: 灵魂, 倩影, 陆牧, 无害, 划下, 龙力, 天魔, 千层,
# Nearest to 火焰: 火焰, 一前一后, 想着, 波纹, 黑雾, 不必要, 能量, 不受,
# Nearest to 萧薰儿: 萧薰儿, 想到, 请动, 愿助, 支持, 瓶, 脑中, 微竖,
# Nearest to 药老: 药老, 咆哮声, 看看, 挥, 速战速决, 这不怪, 砸, 雅涵,
# Nearest to 天阶: 天阶, 沉默, 紧绷着, 不慎, 韩冲, 一扯, 二十岁, 还给,
# Nearest to 云岚宗: 云岚宗, 巨熊, 精神, 咕, 老杂, 四个, 坑痕, 低阶,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 第六, 十六七, 略有, 蜈崖, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 回过, 那卷, 由于, 眼珠子, 迷, 齐全, 注意,
# Average loss at step  42000 :  4.667814309239388
# Average loss at step  44000 :  4.594269776582718
# Average loss at step  46000 :  4.4568625376224515
# Average loss at step  48000 :  5.932787975072861
# Average loss at step  50000 :  5.959449058294296
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 众人, 初步,
# Nearest to 灵魂: 灵魂, 陆牧, 倩影, 无害, 划下, 千层, 紫龙, 十二岁,
# Nearest to 火焰: 火焰, 一前一后, 想着, 黑雾, 波纹, 不必要, 不受, 其中,
# Nearest to 萧薰儿: 萧薰儿, 想到, 请动, 愿助, 支持, 脑中, 瓶, 立,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 挥, 这不怪, 雅涵,
# Nearest to 天阶: 天阶, 沉默, 紧绷着, 不慎, 一扯, 玉琢, 三滴, 还给,
# Nearest to 云岚宗: 云岚宗, 大不一样, 巨熊, 咕, 精神, 老杂, 四个, 坑痕,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 第六, 略有, 坑坑洼洼, 一弹,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 那卷, 回过, 齐全, 由于, 迷,
# Average loss at step  52000 :  4.8221787981987
# Average loss at step  54000 :  4.26758898293972
# Average loss at step  56000 :  4.277613562941551
# Average loss at step  58000 :  4.216244714975357
# Average loss at step  60000 :  4.353988472819328
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 众人, 屹立,
# Nearest to 灵魂: 灵魂, 能量, 倩影, 陆牧, 划下, 无害, 千层, 紫龙,
# Nearest to 火焰: 火焰, 一前一后, 想着, 波纹, 能量, 不必要, 黑雾, 修炼法,
# Nearest to 萧薰儿: 萧薰儿, 想到, 请动, 愿助, 支持, 脑中, 立, 微竖,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 挥, 这不怪, 雅涵,
# Nearest to 天阶: 天阶, 沉默, 紧绷着, 不慎, 一扯, 玉琢, 三滴, 无法形容,
# Nearest to 云岚宗: 云岚宗, 巨熊, 大不一样, 咕, 老杂, 四个, 精神, 低阶,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 第六, 略有, 坑坑洼洼, 一弹,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 回过, 齐全, 那卷, 云韵玉,
# Average loss at step  62000 :  4.276278312683106
# Average loss at step  64000 :  4.247135238409042
# Average loss at step  66000 :  4.220157504200936
# Average loss at step  68000 :  4.208501244664192
# Average loss at step  70000 :  4.212224585771561
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 古河, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 倩影, 陆牧, 划下, 无害, 十二岁, 紫龙,
# Nearest to 火焰: 火焰, 能量, 波纹, 一前一后, 想着, 黑雾, 不必要, 其中,
# Nearest to 萧薰儿: 萧薰儿, 请动, 想到, 愿助, 支持, 脑中, 微竖, 立,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 挥, 这不怪, 雅涵,
# Nearest to 天阶: 天阶, 沉默, 紧绷着, 不慎, 玉琢, 一扯, 三滴, 无法形容,
# Nearest to 云岚宗: 云岚宗, 巨熊, 大不一样, 低阶, 四个, 咕, 精神, 那人醒,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 略有, 第六, 坑坑洼洼, 一弹,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 回过, 齐全, 那卷, 云韵玉,
# Average loss at step  72000 :  4.1686906173229215
# Average loss at step  74000 :  4.134872035861015
# Average loss at step  76000 :  4.154234054088593
# Average loss at step  78000 :  4.159255789518356
# Average loss at step  80000 :  4.0600403300523755
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 小医仙, 古河,
# Nearest to 灵魂: 灵魂, 能量, 倩影, 陆牧, 十二岁, 千层, 划下, 无害,
# Nearest to 火焰: 火焰, 能量, 波纹, 黑雾, 一前一后, 想着, 不必要, 光芒,
# Nearest to 萧薰儿: 萧薰儿, 请动, 愿助, 想到, 支持, 脑中, 上绘, 微竖,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 这不怪, 挥, 天而起,
# Nearest to 天阶: 天阶, 沉默, 紧绷着, 玉琢, 三滴, 不慎, 一扯, 无法形容,
# Nearest to 云岚宗: 云岚宗, 巨熊, 大不一样, 低阶, 咕, 四个, 炼, 那人醒,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 略有, 第六, 坑坑洼洼, 一弹,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 回过, 阴沉, 齐全, 那卷,
# Average loss at step  82000 :  4.103041245579719
# Average loss at step  84000 :  4.054537123322487
# Average loss at step  86000 :  3.947337092876434
# Average loss at step  88000 :  3.82128490293026
# Average loss at step  90000 :  3.818159683227539
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 小医仙, 古河,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 划下, 十二岁, 千层, 倩影, 筛选,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 不必要, 一前一后, 光芒, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 愿助, 想到, 支持, 上绘, 脑中, 微竖,
# Nearest to 药老: 药老, 看看, 咆哮声, 若干, 速战速决, 这不怪, 天而起, 挥,
# Nearest to 天阶: 天阶, 紧绷着, 沉默, 三滴, 无法形容, 玉琢, 躲闪, 一扯,
# Nearest to 云岚宗: 云岚宗, 巨熊, 大不一样, 低阶, 咕, 萧家, 四个, 三心二意,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 第六, 略有, 坑坑洼洼, 未加,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 阴沉, 云韵玉, 回过, 齐全,
# Average loss at step  92000 :  3.788462789773941
# Average loss at step  94000 :  3.7895298113822937
# Average loss at step  96000 :  3.7976244647502897
# Average loss at step  98000 :  4.163681050658226
# Average loss at step  100000 :  4.330282639980316
# Nearest to 萧炎: 萧炎, 他, 紫研, 她, 后者, 他们, 小医仙, 众人,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 倩影, 千层, 划下, 紫龙,
# Nearest to 火焰: 火焰, 能量, 黑雾, 一前一后, 波纹, 光芒, 不必要, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 愿助, 支持, 想到, 上绘, 脑中, 立,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 这不怪, 天而起, 挥,
# Nearest to 天阶: 天阶, 紧绷着, 玉琢, 沉默, 三滴, 无法形容, 周折, 躲闪,
# Nearest to 云岚宗: 云岚宗, 巨熊, 大不一样, 萧家, 低阶, 咕, 三心二意, 老落,
# Nearest to 乌坦城: 乌坦城, 差, 唉, 十六七, 略有, 第六, 未加, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 阴沉, 云韵玉, 齐全, 异火太过,
# Average loss at step  102000 :  4.104809590339661
# Average loss at step  104000 :  3.8573168720006943
# Average loss at step  106000 :  3.8728293634653093
# Average loss at step  108000 :  3.8335417474508287
# Average loss at step  110000 :  3.9142981140613555
# Nearest to 萧炎: 萧炎, 他, 紫研, 她, 后者, 他们, 小医仙, 众人,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 千层, 倩影, 划下, 紫龙,
# Nearest to 火焰: 火焰, 能量, 波纹, 一前一后, 黑雾, 光芒, 想着, 不必要,
# Nearest to 萧薰儿: 萧薰儿, 请动, 愿助, 支持, 想到, 上绘, 脑中, 立,
# Nearest to 药老: 药老, 咆哮声, 看看, 若干, 速战速决, 这不怪, 解决, 天而起,
# Nearest to 天阶: 天阶, 紧绷着, 玉琢, 无法形容, 三滴, 沉默, 周折, 添进,
# Nearest to 云岚宗: 云岚宗, 巨熊, 萧家, 大不一样, 三心二意, 炼, 低阶, 老落,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 略有, 未加, 第六, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 阴沉, 云韵玉, 异火太过, 多数,
# Average loss at step  112000 :  3.899307526350021
# Average loss at step  114000 :  3.8668603318929673
# Average loss at step  116000 :  3.87161418902874
# Average loss at step  118000 :  3.851339154601097
# Average loss at step  120000 :  3.849496534705162
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 古河, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 倩影, 划下, 千层, 筛选,
# Nearest to 火焰: 火焰, 能量, 波纹, 黑雾, 光芒, 一前一后, 斗气, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 想到, 脑中, 上绘, 微竖,
# Nearest to 药老: 药老, 看看, 咆哮声, 若干, 速战速决, 这不怪, 解决, 天而起,
# Nearest to 天阶: 天阶, 紧绷着, 玉琢, 无法形容, 三滴, 沉默, 周折, 添进,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 三心二意, 低阶, 炼, 大不一样, 四个,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 略有, 坑坑洼洼, 第六,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 阴沉, 异火太过, 其望, 错愕,
# Average loss at step  122000 :  3.850006876349449
# Average loss at step  124000 :  3.788005366206169
# Average loss at step  126000 :  3.8207023181915285
# Average loss at step  128000 :  3.842789968729019
# Average loss at step  130000 :  3.738982696056366
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 小医仙, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 倩影, 划下, 筛选,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 一前一后, 斗气, 不必要,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 想到, 上绘, 脑中, 微竖,
# Nearest to 药老: 药老, 看看, 咆哮声, 若干, 这不怪, 速战速决, 解决, 天而起,
# Nearest to 天阶: 天阶, 紧绷着, 无法形容, 三滴, 玉琢, 沉默, 周折, 添进,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 云山, 炼, 三心二意, 大不一样, 低阶,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 坑坑洼洼, 略有, 密室,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 眼珠子, 荑, 异火太过, 错愕, 其望,
# Average loss at step  132000 :  3.773565264701843
# Average loss at step  134000 :  3.768445181250572
# Average loss at step  136000 :  3.719662749171257
# Average loss at step  138000 :  3.7085182995796204
# Average loss at step  140000 :  3.6809570792913435
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 小医仙, 他们, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 划下, 筛选, 倩影,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 一前一后, 不必要,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 想到, 上绘, 脑中, 立,
# Nearest to 药老: 药老, 看看, 咆哮声, 若干, 这不怪, 速战速决, 天而起, 解决,
# Nearest to 天阶: 天阶, 无法形容, 三滴, 玉琢, 紧绷着, 沉默, 周折, 躲闪,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 三心二意, 云山, 大不一样, 低阶, 炼,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 坑坑洼洼, 略有, 第六,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 眼珠子, 荑, 异火太过, 错愕, 云韵玉,
# Average loss at step  142000 :  3.6837212200164795
# Average loss at step  144000 :  3.669592042684555
# Average loss at step  146000 :  3.6857023007869723
# Average loss at step  148000 :  3.832786170721054
# Average loss at step  150000 :  3.9083704311847685
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 他们, 小医仙, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 倩影, 筛选, 划下,
# Nearest to 火焰: 火焰, 能量, 黑雾, 光芒, 波纹, 一前一后, 不必要, 不太难,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 想到, 上绘, 立,
# Nearest to 药老: 药老, 看看, 咆哮声, 若干, 这不怪, 速战速决, 天而起, 解决,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 紧绷着, 沉默, 周折, 躲闪,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 三心二意, 云山, 大不一样, 低阶, 炼,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 淤血, 密室, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 阴沉, 荑, 异火太过, 错愕, 其望,
# Average loss at step  152000 :  3.8711853811740875
# Average loss at step  154000 :  3.747919036269188
# Average loss at step  156000 :  3.736033900976181
# Average loss at step  158000 :  3.715900946855545
# Average loss at step  160000 :  3.766975763916969
# Nearest to 萧炎: 萧炎, 他, 紫研, 她, 后者, 他们, 小医仙, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 倩影, 淡金颜, 筛选,
# Nearest to 火焰: 火焰, 能量, 波纹, 黑雾, 光芒, 一前一后, 想着, 这样一来,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 想到, 上绘, 立,
# Nearest to 药老: 药老, 看看, 若干, 咆哮声, 这不怪, 速战速决, 天而起, 解决,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 紧绷着, 斗王, 周折, 添进,
# Nearest to 云岚宗: 云岚宗, 巨熊, 萧家, 三心二意, 炼, 云山, 四个, 深藏,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 密室, 淤血, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 本皇, 眼珠子, 荑, 阴沉, 异火太过, 多数, 不难想象,
# Average loss at step  162000 :  3.7891723449230192
# Average loss at step  164000 :  3.7687705488204957
# Average loss at step  166000 :  3.7447113642692567
# Average loss at step  168000 :  3.738787173867226
# Average loss at step  170000 :  3.768738670349121
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 柳擎, 古河, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 淡金颜, 千层, 倩影, 筛选,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 想着, 一前一后,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 上绘, 想到, 立,
# Nearest to 药老: 药老, 看看, 若干, 咆哮声, 这不怪, 速战速决, 天而起, 解决,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 紧绷着, 周折, 添进, 躲闪,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 云山, 斗宗, 三心二意, 深藏, 炼,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 密室, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 异火太过, 眼珠子, 不难想象, 错愕, 荑,
# Average loss at step  172000 :  3.7186418212652206
# Average loss at step  174000 :  3.6950034971833228
# Average loss at step  176000 :  3.6879838584661484
# Average loss at step  178000 :  3.7360369510650635
# Average loss at step  180000 :  3.677383477807045
# Nearest to 萧炎: 萧炎, 他, 她, 后者, 紫研, 小医仙, 他们, 韩枫,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 千层, 淡金颜, 倩影,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 不太难, 一前一后,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 上绘, 脑中, 想到, 立,
# Nearest to 药老: 药老, 看看, 若干, 咆哮声, 这不怪, 速战速决, 天而起, 解决,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 紧绷着, 周折, 添进, 躲闪,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 炼, 深藏, 三心二意, 低阶,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 密室, 淤血, 坑坑洼洼,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 异火太过, 眼珠子, 不难想象, 错愕, 荑,
# Average loss at step  182000 :  3.642860795855522
# Average loss at step  184000 :  3.6929355697631836
# Average loss at step  186000 :  3.6164198855161667
# Average loss at step  188000 :  3.6371322667598722
# Average loss at step  190000 :  3.6327460936307907
# Nearest to 萧炎: 萧炎, 他, 她, 后者, 紫研, 小医仙, 他们, 古河,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 淡金颜, 划下, 筛选,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 粉, 一前一后,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 上绘, 立, 微竖,
# Nearest to 药老: 药老, 看看, 若干, 咆哮声, 这不怪, 速战速决, 天而起, 电击,
# Nearest to 天阶: 天阶, 无法形容, 三滴, 玉琢, 斗王, 紧绷着, 萧家, 添进,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 三心二意, 炼, 深藏, 她,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 未加, 密室, 一族, 淤血,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 异火太过, 不难想象, 错愕, 眼珠子, 荑,
# Average loss at step  192000 :  3.6307845491170885
# Average loss at step  194000 :  3.5889670586586
# Average loss at step  196000 :  3.632620720744133
# Average loss at step  198000 :  3.6657609812021255
# Average loss at step  200000 :  3.8097897534370424
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 他们, 小医仙, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 无力, 蛮不讲理, 淡金颜,
# Nearest to 火焰: 火焰, 能量, 黑雾, 光芒, 波纹, 一前一后, 不太难, 留言,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 立, 上绘, 微竖,
# Nearest to 药老: 药老, 看看, 若干, 咆哮声, 这不怪, 速战速决, 天而起, 电击,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 斗王, 紧绷着, 萧家, 添进,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 三心二意, 深藏, 老落, 炼,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 密室, 未加, 一族, 淤血,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 异火太过, 不难想象, 错愕, 眼珠子, 荑,
# Average loss at step  202000 :  3.788775012731552
# Average loss at step  204000 :  3.701139026880264
# Average loss at step  206000 :  3.6595235486030577
# Average loss at step  208000 :  3.662702609539032
# Average loss at step  210000 :  3.6731562258005144
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 他们, 韩枫, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 淡金颜, 蛮不讲理, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 一前一后, 想着, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 立, 上绘, 微竖,
# Nearest to 药老: 药老, 若干, 看看, 咆哮声, 这不怪, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 玉琢, 三滴, 紧绷着, 添进, 周折,
# Nearest to 云岚宗: 云岚宗, 萧家, 巨熊, 云山, 三心二意, 炼, 深藏, 百条,
# Nearest to 乌坦城: 乌坦城, 差, 十六七, 唉, 密室, 未加, 淤血, 古族,
# Nearest to 惊诧: 惊诧, 本皇, 不难想象, 异火太过, 阴沉, 错愕, 眼珠子, 聪明,
# Average loss at step  212000 :  3.741652429819107
# Average loss at step  214000 :  3.7107094036340715
# Average loss at step  216000 :  3.6798510195016862
# Average loss at step  218000 :  3.6729827983379364
# Average loss at step  220000 :  3.708419477939606
# Nearest to 萧炎: 萧炎, 他, 她, 紫研, 后者, 林焱, 小医仙, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 淡金颜, 千层, 无力,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 想着, 斗气, 一前一后,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 立, 要是, 微竖,
# Nearest to 药老: 药老, 若干, 看看, 咆哮声, 这不怪, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 三滴, 斗王, 周折, 添进, 紧绷着,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 他们, 深藏, 三心二意, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 密室, 未加, 淤血, 古族,
# Nearest to 惊诧: 惊诧, 本皇, 阴沉, 不难想象, 错愕, 异火太过, 聪明, 其望,
# Average loss at step  222000 :  3.663339131951332
# Average loss at step  224000 :  3.633897954940796
# Average loss at step  226000 :  3.6318877987861633
# Average loss at step  228000 :  3.6834297978878023
# Average loss at step  230000 :  3.633955027341843
# Nearest to 萧炎: 萧炎, 他, 她, 后者, 紫研, 小医仙, 韩枫, 他们,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 千层, 淡金颜, 无力,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 想着, 团,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 微竖, 立, 要是,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 三滴, 玉琢, 斗王, 添进, 周折, 紧绷着,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 深藏, 三心二意, 他, 第三层,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 密室, 未加, 古族, 淤血,
# Nearest to 惊诧: 惊诧, 本皇, 不难想象, 阴沉, 错愕, 异火太过, 聪明, 其望,
# Average loss at step  232000 :  3.576104671359062
# Average loss at step  234000 :  3.639735607147217
# Average loss at step  236000 :  3.5731453380584717
# Average loss at step  238000 :  3.579556508421898
# Average loss at step  240000 :  3.58646751499176
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 小医仙, 他们, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 千层, 无力, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 斗气, 异火, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 愿助, 脑中, 立, 微竖, 要是,
# Nearest to 药老: 药老, 看看, 若干, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 玉琢, 三滴, 高阶, 躲闪, 周折,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 三心二意, 深藏, 老落, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 密室, 古族, 未加, 淤血,
# Nearest to 惊诧: 惊诧, 阴沉, 不难想象, 本皇, 错愕, 异火太过, 聪明, 其望,
# Average loss at step  242000 :  3.5947490878105164
# Average loss at step  244000 :  3.5722304282188415
# Average loss at step  246000 :  3.563333023428917
# Average loss at step  248000 :  3.585473069906235
# Average loss at step  250000 :  3.7608917324543
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 小医仙, 他们, 前者,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无力, 千层, 蛮不讲理, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 光芒, 波纹, 金光, 不太难, 异火,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 愿助, 立, 微竖, 要是,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 玉琢, 高阶, 三滴, 周折, 躲闪,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 三心二意, 巨熊, 深藏, 老落, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 古族, 密室, 淤血, 未加,
# Nearest to 惊诧: 惊诧, 不难想象, 阴沉, 错愕, 本皇, 异火太过, 其望, 聪明,
# Average loss at step  252000 :  3.7308260436058043
# Average loss at step  254000 :  3.6672504913806914
# Average loss at step  256000 :  3.614241320729256
# Average loss at step  258000 :  3.619829188108444
# Average loss at step  260000 :  3.609777207374573
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 前者, 他们, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 千层, 斗气, 无形, 蛮不讲理,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 粉, 异火, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 愿助, 立, 要是, 微竖,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 玉琢, 三滴, 高阶, 周折, 添进,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 三心二意, 深藏, 这锁魂, 第三层,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 古族, 密室, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 不难想象, 本皇, 错愕, 异火太过, 阴沉, 其望, 聪明,
# Average loss at step  262000 :  3.6954940345287324
# Average loss at step  264000 :  3.6733827059268953
# Average loss at step  266000 :  3.637324780702591
# Average loss at step  268000 :  3.628346920967102
# Average loss at step  270000 :  3.6656376938819886
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 林焱, 柳擎, 韩枫,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无形, 淡金颜, 斗气, 无力,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 异火, 斗气, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 愿助, 微竖, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 玉琢, 斗王, 三滴, 高阶, 功法, 玄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 深藏, 巨熊, 他们, 三心二意, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 古族, 密室, 淤血, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 本皇, 异火太过, 其望, 聪明,
# Average loss at step  272000 :  3.625751044034958
# Average loss at step  274000 :  3.605867827773094
# Average loss at step  276000 :  3.58938044077158
# Average loss at step  278000 :  3.6285971176624296
# Average loss at step  280000 :  3.611266274213791
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 小医仙, 韩枫, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 无形, 无力, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 光芒, 不太难, 斗气, 团,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 立, 愿助,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 高阶, 玉琢, 三滴, 玄阶, 地阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 深藏, 三心二意, 巨熊, 这锁魂, 第三层,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 古族, 密室, 淤血, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 本皇, 异火太过, 其望, 聪明,
# Average loss at step  282000 :  3.5357847480773925
# Average loss at step  284000 :  3.590848957300186
# Average loss at step  286000 :  3.5482225625514983
# Average loss at step  288000 :  3.541605825304985
# Average loss at step  290000 :  3.5633909660577774
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 萧厉, 柳擎, 小医仙,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 无形, 无力, 大地, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 异火, 光芒, 粉, 斗气,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 立, 愿助,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 高阶, 斗王, 玄阶, 玉琢, 三滴, 地阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 三心二意, 深藏, 这锁魂, 巨熊, 丹塔,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 唉, 古族, 密室, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 本皇, 异火太过, 其望, 聪明,
# Average loss at step  292000 :  3.550969653844833
# Average loss at step  294000 :  3.5384112242460253
# Average loss at step  296000 :  3.535224834680557
# Average loss at step  298000 :  3.5570904800891876
# Average loss at step  300000 :  3.6875252685546873
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 韩枫, 前者, 小医仙,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无力, 无形, 大地, 蛮不讲理,
# Nearest to 火焰: 火焰, 能量, 黑雾, 光芒, 波纹, 异火, 粉, 金光,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 微竖, 要是, 立, 师欠,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 咆哮声, 速战速决, 天而起, 小规模,
# Nearest to 天阶: 天阶, 高阶, 无法形容, 斗王, 玄阶, 地阶, 玉琢, 三滴,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 三心二意, 深藏, 丹塔, 这锁魂, 巨熊,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 古族, 唉, 密室, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 本皇, 其望, 聪明,
# Average loss at step  302000 :  3.677187637925148
# Average loss at step  304000 :  3.6384124883413316
# Average loss at step  306000 :  3.5783762444257734
# Average loss at step  308000 :  3.5940799820423126
# Average loss at step  310000 :  3.5775859409570696
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 他们, 前者, 韩枫,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无形, 无力, 大地, 蛮不讲理,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 异火, 粉, 光芒, 想着,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 立, 师欠,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 斗王, 高阶, 玄阶, 地阶, 玉琢, 三滴,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 巨熊, 丹塔, 三心二意, 深藏, 墨家,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 古族, 密室, 唉, 淤血, 地实火,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 异火太过, 本皇, 阴沉, 其望, 聪明,
# Average loss at step  312000 :  3.649258359193802
# Average loss at step  314000 :  3.639986748456955
# Average loss at step  316000 :  3.6089927961826325
# Average loss at step  318000 :  3.6074938969612123
# Average loss at step  320000 :  3.617300545811653
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 韩枫, 柳擎, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 斗气, 无形, 无力, 淡金颜,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 异火, 光芒, 想着, 团,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 天而起, 小规模,
# Nearest to 天阶: 天阶, 无法形容, 玄阶, 高阶, 地阶, 斗王, 玉琢, 三滴,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 墨家, 深藏, 这锁魂, 巨熊,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 古族, 密室, 唉, 淤血, 地实火,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 本皇, 其望, 冷意,
# Average loss at step  322000 :  3.6019389892816545
# Average loss at step  324000 :  3.5864942017793657
# Average loss at step  326000 :  3.5414764307141304
# Average loss at step  328000 :  3.583970704317093
# Average loss at step  330000 :  3.599512583255768
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 韩枫, 小医仙, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 斗气, 无形, 陆牧, 无力, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 波纹, 异火, 光芒, 斗气, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 要是, 脑中, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 小规模, 天而起,
# Nearest to 天阶: 天阶, 高阶, 玄阶, 地阶, 无法形容, 斗王, 三滴, 玉琢,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 深藏, 丹塔, 这锁魂, 院, 第三层,
# Nearest to 乌坦城: 乌坦城, 十六七, 差, 古族, 密室, 唉, 地实火, 淤血,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 本皇, 其望, 冷意,
# Average loss at step  332000 :  3.5226113240718844
# Average loss at step  334000 :  3.536185297727585
# Average loss at step  336000 :  3.5190806806087496
# Average loss at step  338000 :  3.5174385088682176
# Average loss at step  340000 :  3.5389124826192857
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 柳擎, 韩枫, 前者,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 无形, 陆牧, 十二岁, 无力, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光芒, 粉, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 天而起, 小规模,
# Nearest to 天阶: 天阶, 高阶, 玄阶, 斗王, 地阶, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 这锁魂, 老落, 三心二意,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 唉, 一族, 淤血,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 本皇, 其望, 冷意,
# Average loss at step  342000 :  3.5227530903816224
# Average loss at step  344000 :  3.5055561212301254
# Average loss at step  346000 :  3.5144392020702364
# Average loss at step  348000 :  3.5088904720544813
# Average loss at step  350000 :  3.6374338829517363
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 前者, 韩枫, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 无力, 无形, 大地, 蛮不讲理,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光芒, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 微竖, 要是, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 咆哮声, 小规模, 天而起,
# Nearest to 天阶: 天阶, 高阶, 玄阶, 地阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 这锁魂, 魂族, 老落,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 淤血, 一族, 唉,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 本皇, 其望, 冷意,
# Average loss at step  352000 :  3.6331444530487063
# Average loss at step  354000 :  3.6144817551374437
# Average loss at step  356000 :  3.559466662526131
# Average loss at step  358000 :  3.5615607783794405
# Average loss at step  360000 :  3.5482164018154143
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 前者, 柳擎, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无力, 无形, 回音, 不在话下,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 粉, 光芒, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 小规模, 咆哮声, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 高阶, 地阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 魂族, 墨家, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 地实火, 淤血, 唉,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 异火太过, 本皇, 阴沉, 冷意, 其望,
# Average loss at step  362000 :  3.588267262339592
# Average loss at step  364000 :  3.6097903348207474
# Average loss at step  366000 :  3.5912950961589813
# Average loss at step  368000 :  3.5811302597522734
# Average loss at step  370000 :  3.5796384452581407
# Nearest to 萧炎: 萧炎, 后者, 他, 紫研, 她, 韩枫, 林焱, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无形, 不在话下, 无力, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 光芒, 雾气,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 看看, 这不怪, 速战速决, 小规模, 咆哮声, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 魂族, 院, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 地实火, 淤血, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 本皇, 冷意, 其望,
# Average loss at step  372000 :  3.583289546608925
# Average loss at step  374000 :  3.5595374945402147
# Average loss at step  376000 :  3.5281695892214775
# Average loss at step  378000 :  3.5416237881183625
# Average loss at step  380000 :  3.5712566245794295
# Nearest to 萧炎: 萧炎, 后者, 他, 韩枫, 紫研, 她, 萧厉, 小医仙,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无形, 斗气, 无力, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 团, 光芒,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 要是, 微竖, 脑中, 师欠, 立,
# Nearest to 药老: 药老, 若干, 这不怪, 看看, 速战速决, 小规模, 天而起, 咆哮声,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 魔炎谷, 丹塔, 深藏, 魂族, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 地实火, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 本皇, 冷意, 其望,
# Average loss at step  382000 :  3.512347297668457
# Average loss at step  384000 :  3.4970502294301986
# Average loss at step  386000 :  3.531618180513382
# Average loss at step  388000 :  3.4805807691812514
# Average loss at step  390000 :  3.4979587951898576
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 萧厉, 韩枫, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 斗气, 无形, 无力, 不在话下,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 粉, 火浪, 金光,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 要是, 脑中, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 这不怪, 看看, 速战速决, 小规模, 天而起, 咆哮声,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 这锁魂, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 地实火, 淤血, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  392000 :  3.502944905877113
# Average loss at step  394000 :  3.498633035182953
# Average loss at step  396000 :  3.465670014977455
# Average loss at step  398000 :  3.4937614480257033
# Average loss at step  400000 :  3.562454403042793
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 韩枫, 她, 柳擎, 古元,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 无力, 毁灭, 无形, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 金光, 波纹, 光芒, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 这不怪, 看看, 速战速决, 小规模, 天而起, 咆哮声,
# Nearest to 天阶: 天阶, 玄阶, 高阶, 地阶, 斗王, 无法形容, 人类, 功法,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 魂族, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 差, 密室, 地实火, 淤血, 一族,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  402000 :  3.620205361843109
# Average loss at step  404000 :  3.615116667151451
# Average loss at step  406000 :  3.5486152685880663
# Average loss at step  408000 :  3.533671280503273
# Average loss at step  410000 :  3.518231084704399
# Nearest to 萧炎: 萧炎, 他, 后者, 她, 紫研, 前者, 柳擎, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 不在话下, 无力, 无形, 回音,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 粉, 波纹, 火浪, 光芒,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 脑中, 要是, 微竖, 师欠, 立,
# Nearest to 药老: 药老, 若干, 这不怪, 看看, 速战速决, 小规模, 天而起, 咆哮声,
# Nearest to 天阶: 天阶, 玄阶, 高阶, 地阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 魔炎谷, 魂族, 墨家,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 差, 地实火, 石台, 淤血,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 异火太过, 阴沉, 本皇, 冷意, 其望,
# Average loss at step  412000 :  3.554077365398407
# Average loss at step  414000 :  3.5953184539079666
# Average loss at step  416000 :  3.5658683042526245
# Average loss at step  418000 :  3.555790996670723
# Average loss at step  420000 :  3.5450826839208602
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 韩枫, 她, 林焱, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 不在话下, 斗气, 无形, 无力,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 粉, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 要是, 微竖, 脑中, 师欠, 立,
# Nearest to 药老: 药老, 若干, 这不怪, 看看, 速战速决, 小规模, 天而起, 快进去,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 深藏, 魔炎谷, 魂族, 这锁魂,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 地实火, 差, 天焚, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  422000 :  3.57715706884861
# Average loss at step  424000 :  3.529725530743599
# Average loss at step  426000 :  3.511126914858818
# Average loss at step  428000 :  3.504975821495056
# Average loss at step  430000 :  3.557279011249542
# Nearest to 萧炎: 萧炎, 后者, 他, 韩枫, 紫研, 她, 柳擎, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 斗气, 陆牧, 无力, 不在话下, 淡金颜,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光点, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 要是, 微竖, 师欠, 脑中, 立,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 地阶, 玄阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 院, 魂族,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 天焚, 地实火, 差, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  432000 :  3.504106541156769
# Average loss at step  434000 :  3.4538582541942597
# Average loss at step  436000 :  3.5267273037433626
# Average loss at step  438000 :  3.463217080831528
# Average loss at step  440000 :  3.467224156856537
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 韩枫, 萧厉, 柳擎, 前者,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 十二岁, 陆牧, 无力, 大地, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 粉, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 蕴之力,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 地阶, 玄阶, 高阶, 斗王, 无法形容, 人类, 功法,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 魂族, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 天焚, 地实火, 石台, 差,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  442000 :  3.4871380578279494
# Average loss at step  444000 :  3.4709842587709425
# Average loss at step  446000 :  3.4689730978012085
# Average loss at step  448000 :  3.452574980020523
# Average loss at step  450000 :  3.4958309507369996
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 柳擎, 韩枫, 前者, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 大地, 无力, 十二岁, 无形, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 金光, 粉, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 脑中, 要是, 立,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 人类, 功法,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 魂族, 深藏, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 天焚, 地实火, 石台, 差,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  452000 :  3.6152582865953447
# Average loss at step  454000 :  3.5907742782831193
# Average loss at step  456000 :  3.5441089860200883
# Average loss at step  458000 :  3.5009454094171524
# Average loss at step  460000 :  3.5068300751447676
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 柳擎, 前者, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 十二岁, 无力, 不在话下, 大地, 回音,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 粉, 波纹, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 立,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 魂族, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 密室, 天焚, 地实火, 石台, 差,
# Nearest to 惊诧: 惊诧, 不难想象, 错愕, 异火太过, 阴沉, 冷意, 本皇, 其望,
# Average loss at step  462000 :  3.502316506743431
# Average loss at step  464000 :  3.5695005677938463
# Average loss at step  466000 :  3.566194672346115
# Average loss at step  468000 :  3.5247405160665513
# Average loss at step  470000 :  3.5166034214496613
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 韩枫, 前者, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 十二岁, 不在话下, 斗气, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 粉, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 魂族, 深藏, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 天焚, 密室, 地实火, 石台, 遗迹,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  472000 :  3.5576626801490785
# Average loss at step  474000 :  3.5210666913986204
# Average loss at step  476000 :  3.497548829317093
# Average loss at step  478000 :  3.483746608257294
# Average loss at step  480000 :  3.531427146792412
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 她, 萧厉, 紫研, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 无力, 陆牧, 不在话下, 斗气, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 光点, 粉,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 院, 魂族,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 天焚, 密室, 地实火, 石台, 遗迹,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 本皇, 其望,
# Average loss at step  482000 :  3.503668216109276
# Average loss at step  484000 :  3.432021227955818
# Average loss at step  486000 :  3.490680305957794
# Average loss at step  488000 :  3.4463001148700716
# Average loss at step  490000 :  3.4556561740636824
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 萧厉, 柳擎, 韩枫, 前者,
# Nearest to 灵魂: 灵魂, 能量, 无力, 无形, 十二岁, 斗气, 不在话下, 陆牧,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 粉, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 无法形容, 功法, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 魂族, 院,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 天焚, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  492000 :  3.4633487763404847
# Average loss at step  494000 :  3.4643983639478684
# Average loss at step  496000 :  3.4431254279613497
# Average loss at step  498000 :  3.446851618528366
# Average loss at step  500000 :  3.463265626549721
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 柳擎, 前者, 韩枫, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 无力, 十二岁, 大地, 陆牧, 毁灭, 无形,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 波纹, 光点, 火浪, 金光,
# Nearest to 萧薰儿: 萧薰儿, 请动, 支持, 微竖, 师欠, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 小规模, 快进去, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 院, 魂族,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 天焚, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 本皇, 其望,
# Average loss at step  502000 :  3.574761847734451
# Average loss at step  504000 :  3.5550261631011963
# Average loss at step  506000 :  3.533587590098381
# Average loss at step  508000 :  3.4783648793697357
# Average loss at step  510000 :  3.495818281650543
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 她, 林焱, 前者, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 无力, 陆牧, 不在话下, 斗气, 大地,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 粉, 波纹, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 请动, 脑中, 要是, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 快进去, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 深藏, 院, 魂族,
# Nearest to 乌坦城: 乌坦城, 十六七, 古族, 天焚, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 冷意, 异火太过, 阴沉, 本皇, 其望,
# Average loss at step  512000 :  3.4737354321479796
# Average loss at step  514000 :  3.5537889070510866
# Average loss at step  516000 :  3.532090327978134
# Average loss at step  518000 :  3.5084294039011
# Average loss at step  520000 :  3.5133320229053497
# Nearest to 萧炎: 萧炎, 他, 后者, 紫研, 韩枫, 林焱, 柳擎, 她,
# Nearest to 灵魂: 灵魂, 能量, 无力, 十二岁, 斗气, 不在话下, 陆牧, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 粉, 光点, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 支持, 请动, 师欠, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 快进去, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 重兵, 魂族,
# Nearest to 乌坦城: 乌坦城, 天焚, 十六七, 古族, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 好奇, 其望,
# Average loss at step  522000 :  3.535238268852234
# Average loss at step  524000 :  3.504704242825508
# Average loss at step  526000 :  3.4851685606241225
# Average loss at step  528000 :  3.4492693749070167
# Average loss at step  530000 :  3.4972600302696226
# Nearest to 萧炎: 萧炎, 他, 韩枫, 后者, 她, 紫研, 萧厉, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 不在话下, 无力, 十二岁, 大地, 陆牧,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光点, 粉, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 支持, 师欠, 请动, 要是, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 快进去, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 无法形容,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 院, 魂族, 深藏,
# Nearest to 乌坦城: 乌坦城, 天焚, 十六七, 古族, 密室, 石台, 地实火, 遗迹,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 好奇, 惊骇,
# Average loss at step  532000 :  3.506768768310547
# Average loss at step  534000 :  3.4376834231615065
# Average loss at step  536000 :  3.449942950129509
# Average loss at step  538000 :  3.435438012480736
# Average loss at step  540000 :  3.4488141433000563
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 萧厉, 林焱, 紫研, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 无力, 陆牧, 无形, 十二岁, 不在话下,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 火浪, 粉, 光点,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 支持, 请动, 师欠, 脑中, 要是, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 快进去, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 云山, 丹塔, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 十六七, 古族, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 好奇, 其望,
# Average loss at step  542000 :  3.456247348189354
# Average loss at step  544000 :  3.440773503422737
# Average loss at step  546000 :  3.434709229707718
# Average loss at step  548000 :  3.430689099788666
# Average loss at step  550000 :  3.4377163249254226
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 前者, 萧厉, 柳擎, 古元,
# Nearest to 灵魂: 灵魂, 能量, 无力, 无形, 陆牧, 十二岁, 斗气, 大地,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 波纹, 火浪, 金光, 光点,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 请动, 师欠, 脑中, 支持, 要是, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 看看, 速战速决, 快进去, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 无法形容,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 魂族, 院, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 十六七, 古族, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 异火太过, 冷意, 好奇, 讶异,
# Average loss at step  552000 :  3.551185765028
# Average loss at step  554000 :  3.531424502491951
# Average loss at step  556000 :  3.51437130343914
# Average loss at step  558000 :  3.4697591054439543
# Average loss at step  560000 :  3.4819015311002732
# Nearest to 萧炎: 萧炎, 他, 后者, 林焱, 紫研, 前者, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无力, 不在话下, 无形, 回音,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 粉, 波纹, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 脑中, 要是, 请动, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 速战速决, 快进去, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 黄阶, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 魂族, 院, 深藏,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 十六七, 密室, 地实火, 塔, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 好奇, 讶异,
# Average loss at step  562000 :  3.468082709908485
# Average loss at step  564000 :  3.506518715620041
# Average loss at step  566000 :  3.5203403952121737
# Average loss at step  568000 :  3.500171449422836
# Average loss at step  570000 :  3.5027728868722914
# Nearest to 萧炎: 萧炎, 他, 后者, 林焱, 前者, 柳擎, 韩枫, 紫研,
# Nearest to 灵魂: 灵魂, 能量, 无力, 十二岁, 陆牧, 斗气, 不在话下, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 粉, 火浪, 光点,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 要是, 脑中, 请动, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 速战速决, 快进去, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 黄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 十六七, 密室, 地实火, 遗迹, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 异火太过, 好奇, 惊骇,
# Average loss at step  572000 :  3.4980778650045394
# Average loss at step  574000 :  3.4985950509309767
# Average loss at step  576000 :  3.4797001198530197
# Average loss at step  578000 :  3.4483434773087502
# Average loss at step  580000 :  3.470562367796898
# Nearest to 萧炎: 萧炎, 他, 韩枫, 后者, 她, 萧厉, 紫研, 范痨,
# Nearest to 灵魂: 灵魂, 能量, 无力, 斗气, 不在话下, 无形, 陆牧, 十二岁,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 光点, 波纹, 粉, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 要是, 请动, 娃娃亲, 脑中,
# Nearest to 药老: 药老, 这不怪, 若干, 速战速决, 快进去, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 无法形容,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 十六七, 密室, 石台, 地实火, 遗迹,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 冷意, 好奇, 惊骇, 异火太过,
# Average loss at step  582000 :  3.4890040057897567
# Average loss at step  584000 :  3.4223755803108213
# Average loss at step  586000 :  3.43326296210289
# Average loss at step  588000 :  3.4453367367982866
# Average loss at step  590000 :  3.420329448223114
# Nearest to 萧炎: 萧炎, 他, 后者, 萧厉, 韩枫, 柳擎, 林焱, 前者,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 陆牧, 无力, 无形, 十二岁, 不在话下,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 光点, 波纹, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 要是, 请动, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 十六七, 密室, 遗迹, 地实火, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 冷意, 异火太过, 似笑非笑,
# Average loss at step  592000 :  3.4271999711990357
# Average loss at step  594000 :  3.431236485481262
# Average loss at step  596000 :  3.433435271024704
# Average loss at step  598000 :  3.4011605904102327
# Average loss at step  600000 :  3.417350736498833
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 前者, 柳擎, 古元, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 无力, 陆牧, 斗气, 无形, 不在话下, 十二岁,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 光点, 火浪, 波纹, 金光,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 要是, 支持, 请动, 脑中, 娃娃亲,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 无法形容, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 魂族, 院, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 十六七, 遗迹, 地实火, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 冷意, 异火太过, 讶异,
# Average loss at step  602000 :  3.505144070625305
# Average loss at step  604000 :  3.5101002700328827
# Average loss at step  606000 :  3.5196830166578295
# Average loss at step  608000 :  3.468999963283539
# Average loss at step  610000 :  3.464061683177948
# Nearest to 萧炎: 萧炎, 他, 后者, 林焱, 前者, 紫研, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 十二岁, 陆牧, 无力, 无形, 不在话下, 飞跃,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 粉, 光点, 波纹, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 要是, 支持, 脑中, 娃娃亲, 请动,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 黄阶, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 十六七, 遗迹, 帝国, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 冷意, 讶异, 诧异,
# Average loss at step  612000 :  3.445901756167412
# Average loss at step  614000 :  3.4788727877140047
# Average loss at step  616000 :  3.512087254166603
# Average loss at step  618000 :  3.49114031124115
# Average loss at step  620000 :  3.474085143327713
# Nearest to 萧炎: 萧炎, 他, 后者, 林焱, 韩枫, 紫研, 柳擎, 前者,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 十二岁, 不在话下, 斗气, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 光点, 波纹, 粉, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 要是, 脑中, 支持, 娃娃亲, 请动,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 小规模, 看看, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 黄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 万蝎门,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 十六七, 遗迹, 石台, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 诧异, 惊骇, 冷意,
# Average loss at step  622000 :  3.473361428618431
# Average loss at step  624000 :  3.501348652601242
# Average loss at step  626000 :  3.4565990142822267
# Average loss at step  628000 :  3.4380524904727934
# Average loss at step  630000 :  3.4415060993432998
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 她, 前者, 萧厉, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 无力, 陆牧, 不在话下, 十二岁, 无形, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 光点, 波纹, 粉, 火浪,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 要是, 支持, 娃娃亲, 脑中, 请动,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 小规模, 看看, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 黄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 深藏,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 十六七, 遗迹, 石台, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 惊骇, 冷意, 诧异,
# Average loss at step  632000 :  3.476202406048775
# Average loss at step  634000 :  3.4427453660964966
# Average loss at step  636000 :  3.3848784925937654
# Average loss at step  638000 :  3.4551974669694903
# Average loss at step  640000 :  3.4000083446502685
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 萧厉, 前者, 林焱, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 无力, 斗气, 陆牧, 无形, 不在话下, 大地,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光点, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 要是, 娃娃亲, 脑中, 请动,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 看看, 小规模, 天而起,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 人类, 黄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 托大,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 十六七, 遗迹, 石台, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 诧异, 惊骇, 冷意,
# Average loss at step  642000 :  3.4033832129240036
# Average loss at step  644000 :  3.4330803557634355
# Average loss at step  646000 :  3.4095584070682525
# Average loss at step  648000 :  3.394870406150818
# Average loss at step  650000 :  3.404296911239624
# Nearest to 萧炎: 萧炎, 他, 后者, 前者, 韩枫, 古元, 柳擎, 萧厉,
# Nearest to 灵魂: 灵魂, 能量, 无力, 陆牧, 无形, 不在话下, 大地, 回音,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 光点, 火浪, 金光, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 娃娃亲, 要是, 脑中, 请动,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 看看, 小规模, 破解,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 人类, 功法, 黄阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 魂族, 院, 托大,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 石台, 遗迹, 十六七, 地实火,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 好奇, 惊骇, 诧异, 讶异,
# Average loss at step  652000 :  3.432001609921455
# Average loss at step  654000 :  3.5316621755361557
# Average loss at step  656000 :  3.5077907718420027
# Average loss at step  658000 :  3.469811218380928
# Average loss at step  660000 :  3.4316657048463823
# Nearest to 萧炎: 萧炎, 他, 后者, 前者, 林焱, 紫研, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 无形, 十二岁, 不在话下, 回音,
# Nearest to 火焰: 火焰, 黑雾, 能量, 异火, 光点, 粉, 火浪, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 娃娃亲, 要是, 脑中, 中如,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 小规模, 破解, 看看,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 黄阶, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 云山, 魔炎谷, 院, 魂族, 深藏,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 遗迹, 十六七, 塔, 石台,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 诧异, 阴沉, 好奇, 惊骇, 讶异,
# Average loss at step  662000 :  3.441658587694168
# Average loss at step  664000 :  3.4408461307287217
# Average loss at step  666000 :  3.5042458062171935
# Average loss at step  668000 :  3.488748087048531
# Average loss at step  670000 :  3.4618155645132065
# Nearest to 萧炎: 萧炎, 他, 林焱, 后者, 紫研, 韩枫, 柳擎, 前者,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 不在话下, 无形, 十二岁, 斗气,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光点, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 娃娃亲, 支持, 要是, 脑中, 中如,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 小规模, 破解, 看看,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 黄阶, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 魔炎谷, 云山, 院, 托大, 魂族,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 遗迹, 石台, 塔, 十六七,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 诧异, 阴沉, 惊骇, 好奇, 讶异,
# Average loss at step  672000 :  3.452674790024757
# Average loss at step  674000 :  3.48595290017128
# Average loss at step  676000 :  3.463058516263962
# Average loss at step  678000 :  3.427178087949753
# Average loss at step  680000 :  3.4102937693595887
# Nearest to 萧炎: 萧炎, 他, 后者, 韩枫, 柳擎, 前者, 范痨, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 不在话下, 力量, 十二岁, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 波纹, 光点, 火浪, 粉,
# Nearest to 萧薰儿: 萧薰儿, 微竖, 师欠, 支持, 娃娃亲, 要是, 蕴之力, 中如,
# Nearest to 药老: 药老, 这不怪, 若干, 快进去, 速战速决, 小规模, 破解, 看看,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 高阶, 斗王, 功法, 黄阶, 人类,
# Nearest to 云岚宗: 云岚宗, 萧家, 丹塔, 魔炎谷, 云山, 院, 魂族, 托大,
# Nearest to 乌坦城: 乌坦城, 天焚, 古族, 密室, 遗迹, 石台, 十六七, 塔,
# Nearest to 惊诧: 惊诧, 错愕, 不难想象, 阴沉, 诧异, 惊骇, 好奇, 讶异,
# Average loss at step  682000 :  3.474775228381157
# Average loss at step  684000 :  3.436786734223366
# Average loss at step  686000 :  3.3766657598018646
# Average loss at step  688000 :  3.4311534744501113
# Average loss at step  690000 :  3.374006179213524
# Nearest to 萧炎: 萧炎, 他, 韩枫, 后者, 前者, 萧厉, 她, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 陆牧, 无力, 斗气, 无形, 毁灭, 大地,
# ...
# Average loss at step  2768000 :  3.1948226910829542
# Average loss at step  2770000 :  3.2191985223293305
# Nearest to 萧炎: 萧炎, 他, 古元, 萧厉, 柳擎, 魂玉, 韩枫, 蝎山,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 赏赐, 尽量少, 力量, 一时半会, 回采,
# Nearest to 火焰: 火焰, 异火, 能量, 黑雾, 火苗, 火海, 浓雾, 冰层,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 自信, 老狮, 儿沉,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 对战, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 高阶, 那紫火, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 炎盟, 萧族, 宗内,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 崂, 帝国, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 惊愕,
# Average loss at step  2772000 :  3.2510702979564665
# Average loss at step  2774000 :  3.221486840248108
# Average loss at step  2776000 :  3.236780492186546
# Average loss at step  2778000 :  3.2257850546836853
# Average loss at step  2780000 :  3.209108608841896
# Nearest to 萧炎: 萧炎, 他, 穆力, 林焱, 蝎山, 白程, 木战, 古元,
# Nearest to 灵魂: 灵魂, 能量, 回采, 赏赐, 斗气, 力量, 尽量少, 全盛时期,
# Nearest to 火焰: 火焰, 冰层, 黑雾, 能量, 异火, 火苗, 浓雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 儿沉, 自信, 老狮,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 两败俱伤, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 萧家, 磐门, 丹塔, 曹家, 萧族, 炎盟, 叶家,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 云岚宗, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2782000 :  3.201124192714691
# Average loss at step  2784000 :  3.2239925400018694
# Average loss at step  2786000 :  3.252258042216301
# Average loss at step  2788000 :  3.241103956580162
# Average loss at step  2790000 :  3.2319066291451453
# Nearest to 萧炎: 萧炎, 他, 木战, 萧厉, 穆力, 柳擎, 林焱, 范痨,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 赏赐, 回采, 力量, 天凰, 人体,
# Nearest to 火焰: 火焰, 能量, 异火, 冰层, 火苗, 黑雾, 浓雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 儿沉, 自信,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 两败俱伤, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 丹塔, 磐门, 萧家, 曹家, 宗内, 炎盟, 院,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 天焚, 帝国,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2792000 :  3.2414802698493004
# Average loss at step  2794000 :  3.266846786022186
# Average loss at step  2796000 :  3.230620978355408
# Average loss at step  2798000 :  3.207359033167362
# Average loss at step  2800000 :  3.2169560326337816
# Nearest to 萧炎: 萧炎, 他, 萧厉, 韩枫, 后者, 古元, 范痨, 魂玉,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 回采, 力量, 赏赐, 心急火燎, 压出,
# Nearest to 火焰: 火焰, 能量, 异火, 黑雾, 火苗, 冰层, 波纹, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 她, 儿沉,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 对战, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 宗内, 院, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 云岚宗, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2802000 :  3.2492647132873533
# Average loss at step  2804000 :  3.2200767806768416
# Average loss at step  2806000 :  3.1782977668642998
# Average loss at step  2808000 :  3.2169248287677763
# Average loss at step  2810000 :  3.187901520371437
# Nearest to 萧炎: 萧炎, 他, 古元, 萧厉, 韩枫, 林焱, 蝎山, 后者,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 赏赐, 回采, 力量, 嫌生, 天凰,
# Nearest to 火焰: 火焰, 能量, 异火, 黑雾, 火海, 火苗, 冰层, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 儿沉, 自信,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 对战, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 宗内, 院, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 云岚宗, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2812000 :  3.2111508969664575
# Average loss at step  2814000 :  3.2415328446626663
# Average loss at step  2816000 :  3.234035497188568
# Average loss at step  2818000 :  3.2168562064766886
# Average loss at step  2820000 :  3.2010094358325003
# Nearest to 萧炎: 萧炎, 他, 古元, 柳擎, 魂玉, 萧厉, 蝎山, 韩枫,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 力量, 压出, 回采, 全盛时期,
# Nearest to 火焰: 火焰, 异火, 黑雾, 能量, 火苗, 火海, 冰层, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 自信, 儿沉,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 对战, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 高阶, 那紫火, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 宗内, 炎盟, 萧族,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 云岚宗, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2822000 :  3.2353679325580598
# Average loss at step  2824000 :  3.247943979084492
# Average loss at step  2826000 :  3.220332536816597
# Average loss at step  2828000 :  3.224466495871544
# Average loss at step  2830000 :  3.203495836019516
# Nearest to 萧炎: 萧炎, 他, 林焱, 穆力, 紫研, 古元, 后者, 蝎山,
# Nearest to 灵魂: 灵魂, 能量, 赏赐, 斗气, 回采, 力量, 心急火燎, 龙凰,
# Nearest to 火焰: 火焰, 冰层, 黑雾, 异火, 火苗, 能量, 浓雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 她, 老狮, 自信,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 两败俱伤, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 高阶, 那紫火, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 萧族, 叶家, 院,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 云岚宗, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2832000 :  3.202399362564087
# Average loss at step  2834000 :  3.20759037232399
# Average loss at step  2836000 :  3.2523882302045823
# Average loss at step  2838000 :  3.25032923746109
# Average loss at step  2840000 :  3.215567632317543
# Nearest to 萧炎: 萧炎, 他, 林焱, 木战, 萧厉, 穆力, 法犸, 她,
# Nearest to 灵魂: 灵魂, 能量, 赏赐, 斗气, 力量, 人体, 回采, 龙凰,
# Nearest to 火焰: 火焰, 能量, 异火, 冰层, 火苗, 浓雾, 黑雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 她, 老狮, 儿沉,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 五百八十五, 两败俱伤, 二章,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 萧家, 磐门, 丹塔, 曹家, 宗内, 慕兰谷, 院,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 帝国, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2842000 :  3.2326824125051496
# Average loss at step  2844000 :  3.273000331044197
# Average loss at step  2846000 :  3.228057286143303
# Average loss at step  2848000 :  3.214360758304596
# Average loss at step  2850000 :  3.206332163989544
# Nearest to 萧炎: 萧炎, 萧厉, 古元, 他, 韩枫, 后者, 法犸, 蝎山,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 力量, 回采, 赏赐, 心急火燎, 全盛时期,
# Nearest to 火焰: 火焰, 能量, 异火, 火苗, 冰层, 黑雾, 火海, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 她, 老狮, 儿沉,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 二章, 五百八十五, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 高阶, 隐世, 风属,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 曹家, 萧族, 院,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 帝国, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2852000 :  3.2405235062837603
# Average loss at step  2854000 :  3.2272392365932463
# Average loss at step  2856000 :  3.176785031437874
# Average loss at step  2858000 :  3.209532316207886
# Average loss at step  2860000 :  3.1877364206910133
# Nearest to 萧炎: 萧炎, 他, 萧厉, 古元, 韩枫, 林焱, 柳擎, 法犸,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 回采, 全盛时期, 交碰, 尽量少,
# Nearest to 火焰: 火焰, 能量, 异火, 黑雾, 火海, 冰层, 波纹, 火苗,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 儿沉, 木,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 五百八十五, 对战, 两败俱伤,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 隐世, 风属, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 曹家, 炎盟, 萧族,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 崂, 帝国, 天焚,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2862000 :  3.1977250096797945
# Average loss at step  2864000 :  3.2465413757562636
# Average loss at step  2866000 :  3.2286115089654923
# Average loss at step  2868000 :  3.209932869195938
# Average loss at step  2870000 :  3.205415746808052
# Nearest to 萧炎: 萧炎, 他, 古元, 后者, 韩枫, 蝎山, 魂玉, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 一时半会, 尽量少, 力量, 全盛时期,
# Nearest to 火焰: 火焰, 异火, 黑雾, 能量, 火苗, 火海, 波纹, 冰层,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 老狮, 儿沉, 木,
# Nearest to 药老: 药老, 快进去, 这不怪, 一搏, 老点, 二章, 五百八十五, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 曹家, 炎盟, 萧族,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 帝国, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2872000 :  3.230386453807354
# Average loss at step  2874000 :  3.2545292296409607
# Average loss at step  2876000 :  3.2091319835186005
# Average loss at step  2878000 :  3.2155885705947878
# Average loss at step  2880000 :  3.200186335325241
# Nearest to 萧炎: 萧炎, 他, 林焱, 穆力, 紫研, 古元, 蝎山, 萧厉,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 回采, 赏赐, 尽量少, 力量, 无形,
# Nearest to 火焰: 火焰, 黑雾, 冰层, 能量, 火苗, 异火, 浓雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 她, 儿沉, 木,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 五百八十五, 二章, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 曹家, 宗内, 院, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 帝国, 塔,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2882000 :  3.2088233531713484
# Average loss at step  2884000 :  3.196871001362801
# Average loss at step  2886000 :  3.2410333248376846
# Average loss at step  2888000 :  3.246656409859657
# Average loss at step  2890000 :  3.2193973361849784
# Nearest to 萧炎: 萧炎, 他, 木战, 萧厉, 范痨, 韩枫, 穆力, 柳擎,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 力量, 回采, 尽量少, 人体,
# Nearest to 火焰: 火焰, 能量, 异火, 冰层, 火苗, 黑雾, 浓雾, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 她, 儿沉, 老狮,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 五百八十五, 对战, 二章,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 曹家, 墨家, 慕兰谷,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 崂, 帝国, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2892000 :  3.2317645036578178
# Average loss at step  2894000 :  3.2661740208268166
# Average loss at step  2896000 :  3.2341601440906524
# Average loss at step  2898000 :  3.2271828591823577
# Average loss at step  2900000 :  3.192429419517517
# Nearest to 萧炎: 萧炎, 他, 萧厉, 古元, 韩枫, 后者, 范痨, 柳擎,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 回采, 力量, 心急火燎, 嫌生, 收缴,
# Nearest to 火焰: 火焰, 能量, 火苗, 异火, 冰层, 黑雾, 火海, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 儿沉, 老狮, 木,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 五百八十五, 二章,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 风属, 隐世, 七品, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 萧族, 炎盟, 曹家,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 帝国, 崂, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2902000 :  3.232090618491173
# Average loss at step  2904000 :  3.2366417071819304
# Average loss at step  2906000 :  3.189942505478859
# Average loss at step  2908000 :  3.1866254756450654
# Average loss at step  2910000 :  3.1816461617946623
# Nearest to 萧炎: 萧炎, 他, 萧厉, 古元, 韩枫, 柳擎, 林焱, 法犸,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 回采, 交碰, 赏赐, 毁灭, 移过去,
# Nearest to 火焰: 火焰, 异火, 能量, 黑雾, 冰层, 火苗, 火海, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 儿沉, 木, 老狮,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 五百八十五, 二章,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 炎盟, 萧族, 墨家,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 帝国, 柳家, 崂, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2912000 :  3.1962902812361715
# Average loss at step  2914000 :  3.241525312900543
# Average loss at step  2916000 :  3.234511236488819
# Average loss at step  2918000 :  3.211326772093773
# Average loss at step  2920000 :  3.2130715401172636
# Nearest to 萧炎: 萧炎, 他, 古元, 魂玉, 萧厉, 韩枫, 蝎山, 柳擎,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 赏赐, 交碰, 回采, 无形, 压出,
# Nearest to 火焰: 火焰, 异火, 黑雾, 能量, 火苗, 火海, 冰层, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 儿沉, 自信, 老狮,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 五百八十五, 二章,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 萧族, 炎盟, 曹家,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 崂, 帝国, 密室,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2922000 :  3.2080526191592216
# Average loss at step  2924000 :  3.2674308857917786
# Average loss at step  2926000 :  3.1970368690490725
# Average loss at step  2928000 :  3.217399346590042
# Average loss at step  2930000 :  3.205771154880524
# Nearest to 萧炎: 萧炎, 他, 蝎山, 后者, 木战, 穆力, 林焱, 古元,
# Nearest to 灵魂: 灵魂, 斗气, 赏赐, 能量, 回采, 尽量少, 龙凰, 全盛时期,
# Nearest to 火焰: 火焰, 黑雾, 冰层, 火苗, 能量, 异火, 火海, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 雪魅, 魂厉, 微竖, 儿沉, 老狮, 自信,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 二章, 五百八十五,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 萧族, 宗内, 曹家, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 帝国, 柳家, 塔,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2932000 :  3.211992958664894
# Average loss at step  2934000 :  3.2001914520263672
# Average loss at step  2936000 :  3.22295226418972
# Average loss at step  2938000 :  3.2341788973808288
# Average loss at step  2940000 :  3.2262249569892885
# Nearest to 萧炎: 萧炎, 他, 萧厉, 木战, 林焱, 范痨, 韩枫, 穆力,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 赏赐, 回采, 力量, 尽量少, 人体,
# Nearest to 火焰: 火焰, 能量, 冰层, 火苗, 异火, 黑雾, 浓雾, 毒气,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 木,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 二章, 五百八十五,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 曹家, 慕兰谷, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 帝国, 崂, 联军,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2942000 :  3.2306135939955714
# Average loss at step  2944000 :  3.2521252475976943
# Average loss at step  2946000 :  3.243605942606926
# Average loss at step  2948000 :  3.2223028161525726
# Average loss at step  2950000 :  3.194858979701996
# Nearest to 萧炎: 萧炎, 萧厉, 他, 古元, 后者, 柳擎, 穆力, 范痨,
# Nearest to 灵魂: 灵魂, 斗气, 能量, 力量, 回采, 心急火燎, 收缴, 海绵,
# Nearest to 火焰: 火焰, 能量, 火苗, 黑雾, 异火, 冰层, 火海, 波纹,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 木,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 对战, 二章, 五百八十五,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 萧族, 曹家, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 柳家, 帝国, 崂, 云岚宗,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2952000 :  3.219856312572956
# Average loss at step  2954000 :  3.235874108314514
# Average loss at step  2956000 :  3.1914486036300658
# Average loss at step  2958000 :  3.1820378114581107
# Average loss at step  2960000 :  3.2076257539987565
# Nearest to 萧炎: 萧炎, 他, 萧厉, 韩枫, 古元, 柳擎, 林焱, 后者,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 毁灭, 回采, 交碰, 全盛时期, 无形,
# Nearest to 火焰: 火焰, 能量, 黑雾, 异火, 火苗, 冰层, 火海, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 木,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 二章, 对战, 五百八十五,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 宗内, 丹塔, 萧族, 炎盟, 曹家,
# Nearest to 乌坦城: 乌坦城, 加玛, 石漠, 叶城, 柳家, 崂, 帝国, 云岚宗,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2962000 :  3.177538258552551
# Average loss at step  2964000 :  3.2180109301805495
# Average loss at step  2966000 :  3.229932352185249
# Average loss at step  2968000 :  3.2244635388851166
# Average loss at step  2970000 :  3.1941501265764236
# Nearest to 萧炎: 萧炎, 他, 古元, 萧厉, 韩枫, 柳擎, 蝎山, 后者,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 尽量少, 回采, 全盛时期, 毁灭,
# Nearest to 火焰: 火焰, 异火, 黑雾, 火苗, 能量, 冰层, 火海, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 自信,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 二章, 五百八十五, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 萧族, 曹家, 炎盟,
# Nearest to 乌坦城: 乌坦城, 加玛, 石漠, 叶城, 柳家, 崂, 帝国, 云岚宗,
# Nearest to 惊诧: 惊诧, 诧异, 错愕, 愕然, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2972000 :  3.2071588541269302
# Average loss at step  2974000 :  3.2576975972652433
# Average loss at step  2976000 :  3.2018183234930038
# Average loss at step  2978000 :  3.227255116224289
# Average loss at step  2980000 :  3.2079351670742033
# Nearest to 萧炎: 萧炎, 他, 后者, 蝎山, 穆力, 古元, 紫研, 林焱,
# Nearest to 灵魂: 灵魂, 能量, 赏赐, 尽量少, 斗气, 回采, 人体, 毁灭,
# Nearest to 火焰: 火焰, 冰层, 黑雾, 异火, 火苗, 能量, 火海, 浓雾,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 她,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 二章, 五百八十五, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 七品, 那紫火, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 磐门, 萧家, 丹塔, 宗内, 萧族, 慕兰谷, 曹家,
# Nearest to 乌坦城: 乌坦城, 加玛, 叶城, 石漠, 崂, 柳家, 帝国, 萧潇小嘴,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2982000 :  3.2034462611079215
# Average loss at step  2984000 :  3.196898869752884
# Average loss at step  2986000 :  3.2186507250070573
# Average loss at step  2988000 :  3.2449203494787215
# Average loss at step  2990000 :  3.223008225440979
# Nearest to 萧炎: 萧炎, 他, 萧厉, 林焱, 韩枫, 木战, 她, 白山,
# Nearest to 灵魂: 灵魂, 能量, 斗气, 赏赐, 尽量少, 收缴, 回采, 嫌生,
# Nearest to 火焰: 火焰, 能量, 火苗, 异火, 冰层, 黑雾, 浓雾, 火海,
# Nearest to 萧薰儿: 萧薰儿, 凌影, 魂厉, 雪魅, 微竖, 儿沉, 老狮, 自信,
# Nearest to 药老: 药老, 快进去, 一搏, 这不怪, 老点, 二章, 五百八十五, 对战,
# Nearest to 天阶: 天阶, 玄阶, 地阶, 那紫火, 七品, 风属, 隐世, 高阶,
# Nearest to 云岚宗: 云岚宗, 萧家, 磐门, 丹塔, 宗内, 慕兰谷, 炎盟, 曹家,
# Nearest to 乌坦城: 乌坦城, 加玛, 石漠, 叶城, 帝国, 柳家, 崂, 云岚宗,
# Nearest to 惊诧: 惊诧, 诧异, 愕然, 错愕, 惊异, 惊讶, 惊疑, 讶异,
# Average loss at step  2992000 :  3.2262270785570144
# Average loss at step  2994000 :  3.2310980125665663
# Average loss at step  2996000 :  3.2614072699546814
# Average loss at step  2998000 :  3.2216616208553313

# %% [markdown]
# 读取模型

# %%
saver= tf.train.import_meta_graph('D:/sess/-1000.meta')

# %%
with tf.Session() as sess:

    # load the meta graph and weights
    saver = tf.train.import_meta_graph('D:/sess/-1000.meta')
    saver.restore(sess, tf.train.latest_checkpoint("D:/sess/"))

    # get weights
    graph = tf.get_default_graph()
    fc2_w = graph.get_tensor_by_name("truediv:0")

    print(fc2_w.eval())
# Out:
# INFO:tensorflow:Restoring parameters from D:/sess/-1000
# [[-0.06144057  0.02499304  0.00194109 ...  0.06388251 -0.00429929
#    0.06115478]
#  [ 0.05107442 -0.12265075  0.15208824 ...  0.07488727  0.00135686
#   -0.02145557]
#  [-0.10494224 -0.17098777  0.08450435 ... -0.07129572 -0.08744776
#   -0.12084484]
#  ...
#  [-0.11192498 -0.12843628  0.14747913 ... -0.01921185 -0.09330991
#   -0.13031763]
#  [ 0.02682896 -0.12495162 -0.01443376 ... -0.07170907  0.11928383
#    0.09584372]
#  [-0.03799421 -0.03339894  0.00313361 ...  0.10551418  0.06171379
#    0.05161681]]
